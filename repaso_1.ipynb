# %%
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv')

# %%
data.head(10) # Mostramos las primeras 10 filas
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
# 5      AFG      Asia  Afghanistan  2020-01-10          NaN        0.0
# 6      AFG      Asia  Afghanistan  2020-01-11          NaN        0.0
# 7      AFG      Asia  Afghanistan  2020-01-12          NaN        0.0
# 8      AFG      Asia  Afghanistan  2020-01-13          NaN        0.0
# 9      AFG      Asia  Afghanistan  2020-01-14          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# ...

# %%
data.tail(10) # Mostramos las últimas 10 filas
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 401032      ZWE    Africa  Zimbabwe  2024-05-03     266362.0        0.0
# 401033      ZWE    Africa  Zimbabwe  2024-05-04     266362.0        0.0
# 401034      ZWE    Africa  Zimbabwe  2024-05-05     266362.0        0.0
# 401035      ZWE    Africa  Zimbabwe  2024-05-06     266362.0        0.0
# 401036      ZWE    Africa  Zimbabwe  2024-05-07     266362.0        0.0
# 401037      ZWE    Africa  Zimbabwe  2024-05-08     266362.0        0.0
# 401038      ZWE    Africa  Zimbabwe  2024-05-09     266362.0        0.0
# 401039      ZWE    Africa  Zimbabwe  2024-05-10     266362.0        0.0
# 401040      ZWE    Africa  Zimbabwe  2024-05-11     266362.0        0.0
# 401041      ZWE    Africa  Zimbabwe  2024-05-12     266362.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 401032               0.429        5740.0         0.0                  0.0
# ...

# %%
# Mostramos la cantidad total de registros
total_registros = len(data)
print(f"Tenemos {total_registros} filas")
# Out:
# Tenemos 401042 filas

# %%
# Creamos un dataframe 'data100' que contendrá las primeras 100 filas
data100 = data.head(100)

# Creamos el dataframe 'data100' que contendra 100 registros y 2 columnas: 'location' y 'new_cases_smoothed'
data100 = data100[['location', 'new_cases_smoothed']]
data100
# Out:
#        location  new_cases_smoothed
# 0   Afghanistan                 NaN
# 1   Afghanistan                 NaN
# 2   Afghanistan                 NaN
# 3   Afghanistan                 NaN
# 4   Afghanistan                 NaN
# ..          ...                 ...
# 95  Afghanistan              26.143
# 96  Afghanistan              26.143
# 97  Afghanistan              26.143
# 98  Afghanistan              35.286
# 99  Afghanistan              35.286
#
# [100 rows x 2 columns]

# %%
# Activamos la visualizacion total de los registros en un dataframe
# Cuidado - volver a activar para no causar demoras con muchos registros
pd.set_option('display.max_rows', None)
data100
# Out:
#        location  new_cases_smoothed
# 0   Afghanistan                 NaN
# 1   Afghanistan                 NaN
# 2   Afghanistan                 NaN
# 3   Afghanistan                 NaN
# 4   Afghanistan                 NaN
# 5   Afghanistan               0.000
# 6   Afghanistan               0.000
# 7   Afghanistan               0.000
# 8   Afghanistan               0.000
# 9   Afghanistan               0.000
# 10  Afghanistan               0.000
# 11  Afghanistan               0.000
# 12  Afghanistan               0.000
# 13  Afghanistan               0.000
# 14  Afghanistan               0.000
# 15  Afghanistan               0.000
# 16  Afghanistan               0.000
# 17  Afghanistan               0.000
# 18  Afghanistan               0.000
# 19  Afghanistan               0.000
# 20  Afghanistan               0.000
# 21  Afghanistan               0.000
# 22  Afghanistan               0.000
# 23  Afghanistan               0.000
# 24  Afghanistan               0.000
# ...

# %%
# Restablecemos la visualizacion de registros a 10 (001)
pd.set_option('display.max_rows', 10) # Restauramos la visualizacion de 10 registros
data100
# Out:
#        location  new_cases_smoothed
# 0   Afghanistan                 NaN
# 1   Afghanistan                 NaN
# 2   Afghanistan                 NaN
# 3   Afghanistan                 NaN
# 4   Afghanistan                 NaN
# ..          ...                 ...
# 95  Afghanistan              26.143
# 96  Afghanistan              26.143
# 97  Afghanistan              26.143
# 98  Afghanistan              35.286
# 99  Afghanistan              35.286
#
# [100 rows x 2 columns]

# %%
# Crear un dataframe 'datau' que contendra las 100 ultimas filas y 3 columnas: 'location', 'new_cases_smoothed'.
# Mostrar las 100 filas
datau = data.tail(100)
datau = datau[['location', 'new_cases_smoothed']]
datau
# Out:
#         location  new_cases_smoothed
# 400942  Zimbabwe               4.429
# 400943  Zimbabwe               4.429
# 400944  Zimbabwe               4.429
# 400945  Zimbabwe               4.429
# 400946  Zimbabwe               4.429
# ...          ...                 ...
# 401037  Zimbabwe               0.000
# 401038  Zimbabwe               0.000
# 401039  Zimbabwe               0.000
# 401040  Zimbabwe               0.000
# 401041  Zimbabwe               0.000
#
# [100 rows x 2 columns]

# %%
# Activamos la visualizacion total de los registros en un dataframe
pd.set_option('display.max_rows', None)
datau
# Out:
#         location  new_cases_smoothed
# 400942  Zimbabwe               4.429
# 400943  Zimbabwe               4.429
# 400944  Zimbabwe               4.429
# 400945  Zimbabwe               4.429
# 400946  Zimbabwe               4.429
# 400947  Zimbabwe               4.429
# 400948  Zimbabwe               4.429
# 400949  Zimbabwe               4.429
# 400950  Zimbabwe               1.286
# 400951  Zimbabwe               1.286
# 400952  Zimbabwe               1.286
# 400953  Zimbabwe               1.286
# 400954  Zimbabwe               1.286
# 400955  Zimbabwe               1.286
# 400956  Zimbabwe               1.286
# 400957  Zimbabwe               3.143
# 400958  Zimbabwe               3.143
# 400959  Zimbabwe               3.143
# 400960  Zimbabwe               3.143
# 400961  Zimbabwe               3.143
# 400962  Zimbabwe               3.143
# 400963  Zimbabwe               3.143
# 400964  Zimbabwe               0.714
# 400965  Zimbabwe               0.714
# ...

# %%
# Ponemos el indice de datau en 0
datau.reset_index(drop=True, inplace=True)
datau
# Out:
#     location  new_cases_smoothed
# 0   Zimbabwe               4.429
# 1   Zimbabwe               4.429
# 2   Zimbabwe               4.429
# 3   Zimbabwe               4.429
# 4   Zimbabwe               4.429
# 5   Zimbabwe               4.429
# 6   Zimbabwe               4.429
# 7   Zimbabwe               4.429
# 8   Zimbabwe               1.286
# 9   Zimbabwe               1.286
# 10  Zimbabwe               1.286
# 11  Zimbabwe               1.286
# 12  Zimbabwe               1.286
# 13  Zimbabwe               1.286
# 14  Zimbabwe               1.286
# 15  Zimbabwe               3.143
# 16  Zimbabwe               3.143
# 17  Zimbabwe               3.143
# 18  Zimbabwe               3.143
# 19  Zimbabwe               3.143
# 20  Zimbabwe               3.143
# 21  Zimbabwe               3.143
# 22  Zimbabwe               0.714
# 23  Zimbabwe               0.714
# 24  Zimbabwe               0.714
# 25  Zimbabwe               0.714
# 26  Zimbabwe               0.714
# ...

# %%
# Pones el indice de datau en 1
datau.index = datau.index + 1
datau
pd.set_option('display.max_rows', 10) # Restauramos la visualizacion de 10 registros

# %%
# Creamos un dataframe 'data_peru' que contendrá los registros de Perú
data_peru = data[data['location'] == 'Peru']

# %%
# Regstramo y creamos el dataframe con 3 columnas
data_peru = data_peru[['location', 'date', 'new_cases_smoothed']]
data_peru
# Out:
#        location        date  new_cases_smoothed
# 279499     Peru  2020-01-05                 NaN
# 279500     Peru  2020-01-06                 NaN
# 279501     Peru  2020-01-07                 NaN
# 279502     Peru  2020-01-08                 NaN
# 279503     Peru  2020-01-09                 NaN
# ...         ...         ...                 ...
# 281084     Peru  2024-05-08                 0.0
# 281085     Peru  2024-05-09                 0.0
# 281086     Peru  2024-05-10                 0.0
# 281087     Peru  2024-05-11                 0.0
# 281088     Peru  2024-05-12                 0.0
#
# [1590 rows x 3 columns]

# %%
# Nos piden los datos de agosto 2020 en Peru
# Para ello convertimos la columna 'date' a formato propio 'Datetime' de pandas
# Para realizar operaciones de filtrado en dicha columna
data_peru['date'] = pd.to_datetime(data_peru['date'])

# %%
data_peru
# Out:
#        location       date  new_cases_smoothed
# 279499     Peru 2020-01-05                 NaN
# 279500     Peru 2020-01-06                 NaN
# 279501     Peru 2020-01-07                 NaN
# 279502     Peru 2020-01-08                 NaN
# 279503     Peru 2020-01-09                 NaN
# ...         ...        ...                 ...
# 281084     Peru 2024-05-08                 0.0
# 281085     Peru 2024-05-09                 0.0
# 281086     Peru 2024-05-10                 0.0
# 281087     Peru 2024-05-11                 0.0
# 281088     Peru 2024-05-12                 0.0
#
# [1590 rows x 3 columns]

# %%
# Filtramos los datos de Perú en Agosto 2020 a partir del dataframe 'data_peru' en un 
# nuevo dataframe 'data_peru_agosto_2020'
data_peru_agosto_2020 = data_peru[(data_peru["date"].dt.year == 2020) & (data_peru["date"].dt.month == 8)]
pd.set_option('display.max_rows', None)
data_peru_agosto_2020
# Out:
#        location       date  new_cases_smoothed
# 279708     Peru 2020-08-01            4346.286
# 279709     Peru 2020-08-02            5539.143
# 279710     Peru 2020-08-03            5539.143
# 279711     Peru 2020-08-04            5539.143
# 279712     Peru 2020-08-05            5539.143
# 279713     Peru 2020-08-06            5539.143
# 279714     Peru 2020-08-07            5539.143
# 279715     Peru 2020-08-08            5539.143
# 279716     Peru 2020-08-09            7020.000
# 279717     Peru 2020-08-10            7020.000
# 279718     Peru 2020-08-11            7020.000
# 279719     Peru 2020-08-12            7020.000
# 279720     Peru 2020-08-13            7020.000
# 279721     Peru 2020-08-14            7020.000
# 279722     Peru 2020-08-15            7020.000
# 279723     Peru 2020-08-16            7488.714
# 279724     Peru 2020-08-17            7488.714
# 279725     Peru 2020-08-18            7488.714
# 279726     Peru 2020-08-19            7488.714
# ...

# %%
# Mostrar en grafico de barras en linea
data_peru_agosto_2020.plot(x='date', y='new_cases_smoothed', kind='bar')
# Out:
# <Axes: xlabel='date'>

# %%
pd.set_option('display.max_rows', 10) # Restauramos la visualizacion de 10 registros

# %%
# Filtrar datos de los paises andinos (Peru, Argentina, Bolivia y Chile)
paises_andinos = data[(data['location'] == 'Peru') | (data['location'] == 'Argentina') | (data['location'] == 'Bolivia') | (data['location'] == 'Chile')]
paises_andinos
# Out:
#        iso_code      continent   location        date  total_cases  new_cases  \
# 14310       ARG  South America  Argentina  2020-01-01          NaN        NaN
# 14311       ARG  South America  Argentina  2020-01-02          NaN        NaN
# 14312       ARG  South America  Argentina  2020-01-03          NaN        NaN
# 14313       ARG  South America  Argentina  2020-01-04          NaN        NaN
# 14314       ARG  South America  Argentina  2020-01-05          NaN        0.0
# ...         ...            ...        ...         ...          ...        ...
# 281084      PER  South America       Peru  2024-05-08    4524748.0        0.0
# 281085      PER  South America       Peru  2024-05-09    4524748.0        0.0
# 281086      PER  South America       Peru  2024-05-10    4524748.0        0.0
# 281087      PER  South America       Peru  2024-05-11    4524748.0        0.0
# 281088      PER  South America       Peru  2024-05-12    4524748.0        0.0
#
# ...

# %%
paises_andinos = paises_andinos[['location', 'date', 'new_cases_smoothed']]
paises_andinos
# Out:
#          location        date  new_cases_smoothed
# 14310   Argentina  2020-01-01                 NaN
# 14311   Argentina  2020-01-02                 NaN
# 14312   Argentina  2020-01-03                 NaN
# 14313   Argentina  2020-01-04                 NaN
# 14314   Argentina  2020-01-05                 NaN
# ...           ...         ...                 ...
# 281084       Peru  2024-05-08                 0.0
# 281085       Peru  2024-05-09                 0.0
# 281086       Peru  2024-05-10                 0.0
# 281087       Peru  2024-05-11                 0.0
# 281088       Peru  2024-05-12                 0.0
#
# [6364 rows x 3 columns]

# %%
# Dado que en la columna new_cases_smoothed hay valores NaN, se procede a reemplazarlos por 0
# o es mejor eliminar los registros con valores NaN

# primer eliminamos los registros con valores NaN y los 0
paises_andinos_nn = paises_andinos.dropna(subset=['new_cases_smoothed'])
paises_andinos_nn
# Out:
#          location        date  new_cases_smoothed
# 14319   Argentina  2020-01-10                 0.0
# 14320   Argentina  2020-01-11                 0.0
# 14321   Argentina  2020-01-12                 0.0
# 14322   Argentina  2020-01-13                 0.0
# 14323   Argentina  2020-01-14                 0.0
# ...           ...         ...                 ...
# 281084       Peru  2024-05-08                 0.0
# 281085       Peru  2024-05-09                 0.0
# 281086       Peru  2024-05-10                 0.0
# 281087       Peru  2024-05-11                 0.0
# 281088       Peru  2024-05-12                 0.0
#
# [6340 rows x 3 columns]

# %%
# Agrupamos por pais y sumamos la columna new_cases_smoothed y tener en cuenta que el resultado
# sera un objeto de tipo 'Series' y no un dataframe
paises_andinos_nn = paises_andinos_nn.groupby('location')['new_cases_smoothed'].sum()

# Convertimos el objeto 'Series' a un dataframe
pd.set_option('display.float_format', lambda x: '%.0f' % x) # Formateamos los numeros flotantes
paises_andinos_nn
# Out:
# location
# Argentina   10131825
# Bolivia      1212131
# Chile        5400017
# Peru         4524748
# Name: new_cases_smoothed, dtype: float64

# %%
# trabajamos con paises_andinos_mes para no estropear el dataframe paises_andinos
paises_andinos_mes = paises_andinos.dropna(subset=['new_cases_smoothed'])
paises_andinos_mes
# Out:
#          location        date  new_cases_smoothed
# 14319   Argentina  2020-01-10                   0
# 14320   Argentina  2020-01-11                   0
# 14321   Argentina  2020-01-12                   0
# 14322   Argentina  2020-01-13                   0
# 14323   Argentina  2020-01-14                   0
# ...           ...         ...                 ...
# 281084       Peru  2024-05-08                   0
# 281085       Peru  2024-05-09                   0
# 281086       Peru  2024-05-10                   0
# 281087       Peru  2024-05-11                   0
# 281088       Peru  2024-05-12                   0
#
# [6340 rows x 3 columns]

# %%
# Para ello convertimos la columna 'date' a formato propio 'Datetime' de pandas
# Para realizar operaciones de filtrado en dicha columna
paises_andinos_mes['date'] = pd.to_datetime(paises_andinos_mes['date'])
paises_andinos_mes = paises_andinos_mes.groupby([paises_andinos_mes['date'].dt.year, 'location'])['new_cases_smoothed'].sum().reset_index()
# Agregamos una columna 'total' que es la suma de 'new_cases_smoothed' de todos los años 2020 hasta el 2024
paises_andinos_mes['total'] = paises_andinos_mes.groupby('location')['new_cases_smoothed'].transform('sum')

# Convertimos el objeto 'Series' a un dataframe
pd.set_option('display.float_format', lambda x: '%.0f' % x) # Formateamos los numeros flotantes
paises_andinos_nn
# Out:
# C:\Users\frans\AppData\Local\Temp\ipykernel_20932\1471245574.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   paises_andinos_mes['date'] = pd.to_datetime(paises_andinos_mes['date'])
# location
# Argentina   10131825
# Bolivia      1212131
# Chile        5400017
# Peru         4524748
# Name: new_cases_smoothed, dtype: float64

# %%
# hacemos un pivoteo de paises_andinos_mes
paises_andinos_mes = paises_andinos_mes.unstack()
# reemplzar de 
paises_andinos_mes
# Out:
#     date   location new_cases_smoothed    total
# 0   2020  Argentina            1617090 10131825
# 1   2020    Bolivia             152321  1212131
# 2   2020      Chile             594097  5400017
# 3   2020       Peru            1002179  4524748
# 4   2021  Argentina            3930427 10131825
# ..   ...        ...                ...      ...
# 15  2023       Peru              66442  4524748
# 16  2024  Argentina              55151 10131825
# 17  2024    Bolivia                741  1212131
# 18  2024      Chile              69164  5400017
# 19  2024       Peru              19528  4524748
#
# [20 rows x 4 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
