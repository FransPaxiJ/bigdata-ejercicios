# %%
# %pip install pandas
import pandas as pd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Los datos se encuentran en esta URL: 
# - https://www.sgm.gob.mx/productos/pdf/Anuario_2022_Edicion_2023.pdf
# - https://www.gob.pe/institucion/minem/informes-publicaciones/3614940-produccion-minera 
data = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQGYFyOV4_WV7WdtxMragfxTGlz6SMzAYawgcEV-XgOyDkC-jkvGt5T_ZBBNczZCQ/pub?gid=1089489479&single=true&output=csv", index_col="fecha",)
# el index_col="fecha" es para que la columna fecha sea el indice de la tabla
print(data)
# Out:
#                 mexico         peru
# fecha
# 1/1/2022   566989,8509  466048,3376
# 1/2/2022   551114,1351   457123,306
# 1/3/2022   578896,6378  458613,2803
# 1/4/2022   549129,6706  434813,6111
# 1/5/2022   567840,3357  455856,9245
# 1/6/2022   546294,7213  458377,2532
# 1/7/2022   555366,5589  473181,8703
# 1/8/2022   545444,2365  510742,1622
# 1/9/2022   533253,9548   482498,948
# 1/10/2022  543176,2771  499817,7611
# 1/11/2022    551397,63  469490,5221
# 1/12/2022  541758,8025  534922,7261

# %%
# %pip install ffmpeg
import bar_chart_race as bcarrera

# Remove commas and convert all columns to numeric
data['mexico'] = pd.to_numeric(data['mexico'].str.replace(',', ''))
data['peru'] = pd.to_numeric(data['peru'].str.replace(',', ''))

# Now you can create the bar chart race
bcarrera.bar_chart_race(df=data)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\frans\AppData\Local\Programs\Python\Python39\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(self.df_values.columns)
# c:\Users\frans\AppData\Local\Programs\Python\Python39\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="912" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...
